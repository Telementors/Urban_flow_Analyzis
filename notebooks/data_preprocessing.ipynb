# %%
import polars as pl

df = pl.read_parquet(DATA_PATH)
print(df.shape)
print(df.columns)
df.head()

# %%
DATA_PATH = "C:\Projects\Urban_flow_Analyzis\Urban_Flow_Analytics_Dataset_csv\Urban_Flow_Analytics_Dataset_csv"
